# %%
import requests
FLASK_URL = 'http://127.0.0.1:5000'

Test_user = "test"

# requests.get(FLASK_URL + '/').json()
login = requests.post(FLASK_URL + '/login', json={
    'username':Test_user,
    'password': 'test'})
str(login.json())
# Out:
# "{'message': 'Login success', 'user': {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJmcmVzaCI6ZmFsc2UsImlhdCI6MTY3MDI3NDc0MSwianRpIjoiZTZmZjA5OWQtMTkzNS00OGY2LWFhNGUtMjQwNmZjY2Y3OGFmIiwidHlwZSI6ImFjY2VzcyIsInN1YiI6MSwibmJmIjoxNjcwMjc0NzQxLCJleHAiOjE2NzAyNzU2NDF9.PJrdm9dZQeeDj1BDqFO7MVRWV5WY6cxlEz1RpFjx6pg', 'password': 'sha256$FnV0pg8xkgKvT8y8$1605b1a1f9ecf3d8ec31e776194ef94a4a89199fd4986a127a363d5d6e7b9545', 'userId': 1, 'username': 'test'}}"

# %%
res = requests.get(FLASK_URL + '/transactions/4',)

print(res.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     909         try:
# --> 910             return complexjson.loads(self.text, **kwargs)
#     911         except JSONDecodeError as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...

# %%
def create_test_user(username, password):
    return requests.post(FLASK_URL + '/login', json={
        'username':username,
        'password': password})


users = [create_test_user('test-' + str(i), 'test') for i in range(100)]




def create_test_stash(name, user, walletId):
    return requests.post(FLASK_URL + '/create-stash', json={
        'name':name,
        'userId': user,
        'walletId': walletId},
        headers={'Authorization': 'Bearer ' + user['access_token']}
    )

# %%
users[0].json()
parsed_users = [user.json() for user in users]

# %%
import requests
import random

users_addr = open('users.txt').readlines()[:100]
users_addr = [user_addr.strip() for user_addr in users_addr]
print(users_addr[:5])

i=0
for user in parsed_users[:4]:
    user_wallet = users_addr[i]
    wallet = requests.post(FLASK_URL + '/addwallet', json={
        "address": user_wallet,
        "privateKey":"test-key",
        "userId": user['userId']}
        headers={'Authorization': 'Bearer ' + user['access_token']}
    )


NODE_URL = "https://fullnode.mainnet.aptoslabs.com/v1"
# def get_account_transactions(address):
#     user_dapps = {}
#     response = requests.get(
#         f"{NODE_URL}/accounts/{address}/transactions",
#         params={"limit": 50})
#     print(response.json())

# get_account_transactions(users[0])
# Out:
#   File "<ipython-input-12-4b64a296e875>", line 15
#     headers={'Authorization': 'Bearer ' + user['access_token']}
#     ^
# SyntaxError: invalid syntax

# %%
import time

# %%
with open("users.txt", "r") as f:
    users = f.read().splitlines()
    users = [user.split(",")[0] for user in users]
    print(users[0])
    i=10
    for user in users:
        user_db = create_test_user("user-"+str(i), 'test')
        time.sleep(1)
        i+=1
        
        # 1 -> 30
# Out:
# 0x9ee9892d8600ed0bf65173d801ab75204a16ac2c6f190454a3b98f6bcb99d915
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ce734f3e3725> in <module>
#       6     for user in users:
#       7         user_db = create_test_user("user-"+str(i), 'test')
# ----> 8         time.sleep(1)
#       9         i+=1
#      10
#
# KeyboardInterrupt:
